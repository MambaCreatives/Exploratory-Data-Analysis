# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.linear_model import LinearRegression

# %%
df =pd.read_csv("C://Users//kipal//Downloads//archive//Global Health Statistics.csv")

# %%
df.head(30)
# Out:
#     Country  Year  Disease Name  Disease Category  Prevalence Rate (%)  \
# 0         0  2013             0                 0                 0.95
# 1         1  2002             1                 1                12.46
# 2         2  2015             2                 2                 0.91
# 3         3  2011             3                 3                 4.68
# 4         0  2013             4                 2                 0.83
# 5         4  2011             5                 4                10.99
# 6         5  2013             0                 5                18.42
# 7         6  2007             4                 6                 3.48
# 8         0  2000             6                 7                15.59
# 9         7  2006             7                 7                10.12
# 10        8  2011             8                 5                11.15
# 11        9  2009             9                 8                 3.88
# ...

# %%
df.isnull().sum()
# Out:
# Country                               0
# Year                                  0
# Disease Name                          0
# Disease Category                      0
# Prevalence Rate (%)                   0
# Incidence Rate (%)                    0
# Mortality Rate (%)                    0
# Age Group                             0
# Gender                                0
# Population Affected                   0
# Healthcare Access (%)                 0
# Doctors per 1000                      0
# Hospital Beds per 1000                0
# Treatment Type                        0
# Average Treatment Cost (USD)          0
# Availability of Vaccines/Treatment    0
# Recovery Rate (%)                     0
# DALYs                                 0
# Improvement in 5 Years (%)            0
# Per Capita Income (USD)               0
# Education Index                       0
# Urbanization Rate (%)                 0
# dtype: int64

# %%
df.describe()
# Out:
#                  Year  Prevalence Rate (%)  Incidence Rate (%)  \
# count  1000000.000000       1000000.000000      1000000.000000
# mean      2011.996999            10.047992            7.555005
# std          7.217287             5.740189            4.298947
# min       2000.000000             0.100000            0.100000
# 25%       2006.000000             5.090000            3.840000
# 50%       2012.000000            10.040000            7.550000
# 75%       2018.000000            15.010000           11.280000
# max       2024.000000            20.000000           15.000000
#
#        Mortality Rate (%)  Population Affected  Healthcare Access (%)  \
# count      1000000.000000       1000000.000000         1000000.000000
# mean             5.049919        500735.427363              74.987835
# std              2.859427        288660.116648              14.436345
# min              0.100000          1000.000000              50.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 22 columns):
#  #   Column                              Non-Null Count    Dtype
# ---  ------                              --------------    -----
#  0   Country                             1000000 non-null  object
#  1   Year                                1000000 non-null  int64
#  2   Disease Name                        1000000 non-null  object
#  3   Disease Category                    1000000 non-null  object
#  4   Prevalence Rate (%)                 1000000 non-null  float64
#  5   Incidence Rate (%)                  1000000 non-null  float64
#  6   Mortality Rate (%)                  1000000 non-null  float64
#  7   Age Group                           1000000 non-null  object
#  8   Gender                              1000000 non-null  object
#  9   Population Affected                 1000000 non-null  int64
# ...

# %%
df.shape
# Out:
# (1000000, 22)

# %%
df.tail(30)
# Out:
#         Country  Year  Disease Name  Disease Category  Prevalence Rate (%)  \
# 999970       16  2022            12                 9                10.20
# 999971        4  2024            18                 2                 3.67
# 999972        1  2020            15                 7                14.86
# 999973       16  2000            18                 8                 0.35
# 999974       14  2003            11                 8                14.37
# 999975        0  2004            19                 0                 3.75
# 999976        0  2011             0                 2                 3.73
# 999977       13  2020             8                 1                16.44
# 999978        2  2003             1                 8                16.77
# 999979       18  2009             8                 7                 8.66
# 999980       19  2012            10                 4                14.25
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Disease Name', 'Disease Category',
#        'Prevalence Rate (%)', 'Incidence Rate (%)', 'Mortality Rate (%)',
#        'Age Group', 'Gender', 'Population Affected', 'Healthcare Access (%)',
#        'Doctors per 1000', 'Hospital Beds per 1000', 'Treatment Type',
#        'Average Treatment Cost (USD)', 'Availability of Vaccines/Treatment',
#        'Recovery Rate (%)', 'DALYs', 'Improvement in 5 Years (%)',
#        'Per Capita Income (USD)', 'Education Index', 'Urbanization Rate (%)'],
#       dtype='object')

# %%
df.describe(include="O")
# Out:
#         Country Disease Name Disease Category Age Group   Gender  \
# count   1000000      1000000          1000000   1000000  1000000
# unique       20           20               11         4        3
# top      Russia     COVID-19        Metabolic     19-35     Male
# freq      50532        50404            91332    251201   333676
#
#        Treatment Type Availability of Vaccines/Treatment
# count         1000000                            1000000
# unique              4                                  2
# top           Surgery                                Yes
# freq           250528                             500354

# %%
list(df.Gender.unique())
# Out:
# ['Male', 'Other', 'Female']

# %%
list(df.Country.unique())
# Out:
# ['Italy',
#  'France',
#  'Turkey',
#  'Indonesia',
#  'Saudi Arabia',
#  'USA',
#  'Nigeria',
#  'Australia',
#  'Canada',
#  'Mexico',
#  'China',
#  'South Africa',
#  'Japan',
#  'UK',
#  'Russia',
#  'Brazil',
#  'Germany',
#  'India',
#  'Argentina',
#  'South Korea']

# %%
list(df['Disease Name'].unique())
# Out:
# ['Malaria',
#  'Ebola',
#  'COVID-19',
#  "Parkinson's Disease",
#  'Tuberculosis',
#  'Dengue',
#  'Rabies',
#  'Cholera',
#  'Leprosy',
#  'Cancer',
#  'Diabetes',
#  'Measles',
#  'Zika',
#  "Alzheimer's Disease",
#  'Polio',
#  'Hypertension',
#  'Asthma',
#  'HIV/AIDS',
#  'Influenza',
#  'Hepatitis']

# %%
list(df['Disease Category'].unique())
# Out:
# ['Respiratory',
#  'Parasitic',
#  'Genetic',
#  'Autoimmune',
#  'Bacterial',
#  'Cardiovascular',
#  'Neurological',
#  'Chronic',
#  'Metabolic',
#  'Infectious',
#  'Viral']

# %%
list(df['Treatment Type'].unique())
# Out:
# ['Medication', 'Surgery', 'Vaccination', 'Therapy']

# %%
gender= {"Female": 0,  "Male": 1, "Other": 2} 
df['Gender']= df['Gender'].replace(gender)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\3434061090.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Gender']= df['Gender'].replace(gender)

# %%
treatmenttype= {"Medication": 0,  "Surgery": 1, "Vaccination": 2 ,"Therapy":3} 
df['Treatment Type']= df['Treatment Type'].replace(treatmenttype)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\2646661199.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Treatment Type']= df['Treatment Type'].replace(treatmenttype)

# %%
disease= {"Respiratory": 0,  "Parasitic": 1, "Genetic": 2, "Autoimmune":3 ,"Bacterial" :4 ,"Cardiovascular":5 ,"Neurological":6,"Chronic":7,"Metabolic":8,"Infectious":9,"Viral":10} 
df['Disease Category']= df['Disease Category'].replace(disease)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\2676048869.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Disease Category']= df['Disease Category'].replace(disease)

# %%
df.head()
# Out:
#      Country  Year         Disease Name  Disease Category  \
# 0      Italy  2013              Malaria                 0
# 1     France  2002                Ebola                 1
# 2     Turkey  2015             COVID-19                 2
# 3  Indonesia  2011  Parkinson's Disease                 3
# 4      Italy  2013         Tuberculosis                 2
#
#    Prevalence Rate (%)  Incidence Rate (%)  Mortality Rate (%) Age Group  \
# 0                 0.95                1.55                8.42      0-18
# 1                12.46                8.63                8.75       61+
# 2                 0.91                2.35                6.22     36-60
# 3                 4.68                6.29                3.99      0-18
# 4                 0.83               13.59                7.01       61+
#
#    Gender  Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# 0       1               471007  ...                    7.58               0
# ...

# %%
disease_name_mapping = {
    'Malaria': 0,
    'Ebola': 1,
    'COVID-19': 2,
    "Parkinson's Disease": 3,
    'Tuberculosis': 4,
    'Dengue': 5,
    'Rabies': 6,
    'Cholera': 7,
    'Leprosy': 8,
    'Cancer': 9,
    'Diabetes': 10,
    'Measles': 11,
    'Zika': 12,
    "Alzheimer's Disease": 13,
    'Polio': 14,
    'Hypertension': 15,
    'Asthma': 16,
    'HIV/AIDS': 17,
    'Influenza': 18,
    'Hepatitis': 19
}
df['Disease Name'] = df['Disease Name'].replace(disease_name_mapping)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\4245045814.py:23: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Disease Name'] = df['Disease Name'].replace(disease_name_mapping)

# %%
# Mapping dictionary for 'Country'
country_mapping = {
    'Italy': 0,
    'France': 1,
    'Turkey': 2,
    'Indonesia': 3,
    'Saudi Arabia': 4,
    'USA': 5,
    'Nigeria': 6,
    'Australia': 7,
    'Canada': 8,
    'Mexico': 9,
    'China': 10,
    'South Africa': 11,
    'Japan': 12,
    'UK': 13,
    'Russia': 14,
    'Brazil': 15,
    'Germany': 16,
    'India': 17,
    'Argentina': 18,
    'South Korea': 19
}

# Replace 'Country' column values with mapped integers
df['Country'] = df['Country'].replace(country_mapping)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\3024572251.py:26: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Country'] = df['Country'].replace(country_mapping)

# %%
list(df['Availability of Vaccines/Treatment'].unique())
# Out:
# ['No', 'Yes']

# %%
available= {"No": 0,  "Yes": 1} 
df['Availability of Vaccines/Treatment']= df['Availability of Vaccines/Treatment'].replace(available)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\3487337574.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Availability of Vaccines/Treatment']= df['Availability of Vaccines/Treatment'].replace(available)

# %%
df.head(20)
# Out:
#     Country  Year  Disease Name  Disease Category  Prevalence Rate (%)  \
# 0         0  2013             0                 0                 0.95
# 1         1  2002             1                 1                12.46
# 2         2  2015             2                 2                 0.91
# 3         3  2011             3                 3                 4.68
# 4         0  2013             4                 2                 0.83
# 5         4  2011             5                 4                10.99
# 6         5  2013             0                 5                18.42
# 7         6  2007             4                 6                 3.48
# 8         0  2000             6                 7                15.59
# 9         7  2006             7                 7                10.12
# 10        8  2011             8                 5                11.15
# 11        9  2009             9                 8                 3.88
# ...

# %%
age_mapping = {"0-10": 0, "11-20": 1, "21-30": 2, "31-40": 3,  "36-60": 4 ,"41-50": 5,"51-60": 6, "61+": 7,"0-18":8,"19-35":9}
df['Age Group'] = df['Age Group'].replace(age_mapping)
# Out:
# C:\Users\kipal\AppData\Local\Temp\ipykernel_6276\894365152.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['Age Group'] = df['Age Group'].replace(age_mapping)

# %%
df.head()
# Out:
#    Country  Year  Disease Name  Disease Category  Prevalence Rate (%)  \
# 0        0  2013             0                 0                 0.95
# 1        1  2002             1                 1                12.46
# 2        2  2015             2                 2                 0.91
# 3        3  2011             3                 3                 4.68
# 4        0  2013             4                 2                 0.83
#
#    Incidence Rate (%)  Mortality Rate (%)  Age Group  Gender  \
# 0                1.55                8.42          8       1
# 1                8.63                8.75          7       1
# 2                2.35                6.22          4       1
# 3                6.29                3.99          8       2
# 4               13.59                7.01          7       1
#
#    Population Affected  ...  Hospital Beds per 1000  Treatment Type  \
# 0               471007  ...                    7.58               0
# ...

# %%
target = df["Mortality Rate (%)"]

# %%
train = df.drop("Mortality Rate (%)",axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split( train, target, test_size=0.20)

# %%
model_1 = LinearRegression()
model_2 = xgb.XGBRegressor()
model_3 = RandomForestRegressor()
model = LinearRegression()
model.fit(X_train, y_train)
print(X_train.head())
print(X_train.dtypes)
def convert_range_to_number(value):
    if isinstance(value, str) and '-' in value:
        start, end = map(int, value.split('-'))
        return (start + end) / 2  # Convert range to mean
    elif value == '60+':  # Handle special cases like '60+'
        return 60
    return value
X_train['age'] = X_train['age'].apply(convert_range_to_number)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6276\1535662341.py in ?()
#       1 model_1 = LinearRegression()
#       2 model_2 = xgb.XGBRegressor()
#       3 model_3 = RandomForestRegressor()
#       4 model = LinearRegression()
# ----> 5 model.fit(X_train, y_train)
#       6 print(X_train.head())
#       7 print(X_train.dtypes)
#       8 def convert_range_to_number(value):
#
# ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
pred_1 = model_1.predict(X_test)
pred_2 = model_2.predict(X_test)
pred_3 = model_3.predict(X_test)
